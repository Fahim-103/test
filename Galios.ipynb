# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 galois.ntt([1, 2, 3, 4], modulus=17)
#
# NameError: name 'galois' is not defined

# %%
import galois

# %%
galois.ntt([1, 2, 3, 4], modulus=17)
# Out:
# GF([10,  6, 15,  7], order=17)

# %%
from sympy import ntt, intt

# %%
ntt([1, 2, 3, 4], prime=9*2**3 + 1)
# Out:
# [10, 17, 71, 52]

# %%
list(galois.primitive_roots(31))
# Out:
# [3, 11, 12, 13, 17, 21, 22, 24]

# %%
list(galois.primitive_roots(15))
# Out:
# []

# %%
list(galois.primitive_roots(7681))
# Out:
# [17,
#  31,
#  34,
#  39,
#  41,
#  46,
#  47,
#  51,
#  52,
#  59,
#  65,
#  74,
#  83,
#  85,
#  86,
#  92,
#  93,
#  104,
#  109,
#  117,
#  119,
#  123,
#  124,
#  131,
#  134,
#  136,
#  141,
#  143,
#  148,
#  151,
#  153,
#  155,
#  161,
#  166,
#  167,
#  173,
#  177,
#  179,
#  182,
#  188,
#  191,
#  193,
#  195,
#  197,
#  199,
#  205,
#  211,
#  214,
#  222,
#  226,
#  235,
#  236,
#  247,
#  248,
#  249,
#  253,
#  255,
#  258,
#  259,
#  267,
#  268,
#  271,
#  276,
#  284,
#  286,
#  293,
#  295,
#  301,
#  302,
#  306,
#  312,
#  322,
#  325,
#  326,
#  327,
#  328,
#  337,
#  341,
#  351,
#  356,
#  358,
#  364,
#  367,
#  369,
#  370,
#  372,
#  376,
#  393,
#  397,
#  401,
#  402,
#  408,
#  414,
#  415,
#  425,
#  426,
#  428,
#  429,
#  430,
#  433,
#  434,
#  436,
#  437,
#  444,
#  445,
#  446,
#  451,
#  452,
#  453,
#  460,
#  468,
#  469,
#  472,
#  473,
#  476,
#  487,
#  492,
#  493,
#  494,
#  501,
#  503,
#  509,
#  510,
#  516,
#  517,
#  518,
#  519,
# ...

# %%
pow(17,64,64)
# Out:
# 1
