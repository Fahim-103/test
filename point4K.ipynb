# %%
x = 240

w=21
for i in range(16):
    print ((i*x),pow(w, (i*x), 65537))
# Out:
# 0 1
# 240 24594
# 480 23863
# 720 2787
# 960 57313
# 1200 51663
# 1440 34003
# 1680 17662
# 1920 65529
# 2160 65396
# 2400 5707
# 2640 43241
# 2880 255
# 3120 45455
# 3360 55661
# 3600 55315

# %%
w=21
for i in range(4):
    print ((i*768),pow(w, (i*768), 65537))
# Out:
# 0 1
# 768 16384
# 1536 61441
# 2304 1024

# %%
for i in range(1900):
    print (i,pow(i, 4096, 65537))
# Out:
# 0 0
# 1 1
# 2 1
# 3 64
# 4 1
# 5 65533
# 6 64
# 7 64513
# 8 1
# 9 4096
# 10 65533
# 11 64513
# 12 64
# 13 65536
# 14 64513
# 15 65281
# 16 1
# 17 256
# 18 4096
# 19 16
# 20 65533
# 21 1
# 22 64513
# 23 4
# 24 64
# 25 16
# 26 65536
# 27 65533
# 28 64513
# 29 64513
# 30 65281
# 31 4
# 32 1
# 33 1
# 34 256
# 35 4096
# 36 4096
# 37 61441
# 38 16
# 39 65473
# 40 65533
# 41 4
# 42 1
# 43 65473
# 44 64513
# 45 49153
# 46 4
# 47 64513
# 48 64
# 49 65521
# 50 16
# 51 16384
# 52 65536
# 53 61441
# 54 65533
# 55 4096
# 56 64513
# 57 1024
# 58 64513
# 59 64
# 60 65281
# 61 1024
# 62 4
# 63 64
# 64 1
# 65 4
# 66 1
# 67 4
# 68 256
# 69 256
# 70 4096
# 71 256
# 72 4096
# 73 4
# 74 61441
# 75 1024
# 76 16
# 77 65521
# 78 65473
# 79 256
# 80 65533
# 81 65281
# 82 4
# 83 64
# 84 1
# 85 64513
# 86 65473
# 87 1
# 88 64513
# 89 49153
# 90 49153
# 91 1024
# 92 4
# 93 256
# 94 64513
# 95 65473
# 96 64
# 97 4096
# 98 65521
# 99 64
# 100 16
# 101 64
# 102 16384
# 103 65281
# 104 65536
# 105 65533
# ...

# %%
w=21
for i in range(4097):
    if (pow(w, i, 65537) == 1):
        print (i,pow(w, i, 65537))
# Out:
# 0 1
# 4096 1

# %%
for x in range(4096):
    a = (int) ((65537*x+1)/21)
    if ((((65537*x+1)/21) - a) == 0):
        print ("%3d : %f" % (x ,  ((65537*x+1)/21)))
# Out:
#  16 : 49933.000000
#  37 : 115470.000000
#  58 : 181007.000000
#  79 : 246544.000000
# 100 : 312081.000000
# 121 : 377618.000000
# 142 : 443155.000000
# 163 : 508692.000000
# 184 : 574229.000000
# 205 : 639766.000000
# 226 : 705303.000000
# 247 : 770840.000000
# 268 : 836377.000000
# 289 : 901914.000000
# 310 : 967451.000000
# 331 : 1032988.000000
# 352 : 1098525.000000
# 373 : 1164062.000000
# 394 : 1229599.000000
# 415 : 1295136.000000
# 436 : 1360673.000000
# 457 : 1426210.000000
# 478 : 1491747.000000
# 499 : 1557284.000000
# 520 : 1622821.000000
# 541 : 1688358.000000
# 562 : 1753895.000000
# 583 : 1819432.000000
# 604 : 1884969.000000
# 625 : 1950506.000000
# 646 : 2016043.000000
# 667 : 2081580.000000
# 688 : 2147117.000000
# 709 : 2212654.000000
# 730 : 2278191.000000
# 751 : 2343728.000000
# 772 : 2409265.000000
# 793 : 2474802.000000
# 814 : 2540339.000000
# 835 : 2605876.000000
# 856 : 2671413.000000
# 877 : 2736950.000000
# 898 : 2802487.000000
# 919 : 2868024.000000
# ...
